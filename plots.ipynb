# %%
import plots
plots.make_lmc_plots_mlp(save_plots=False, display=True)
# Out:
# {'mlp_symmetry0': 'MLP', 'mlp_symmetry1_kappa0': '<i>W</i>-MLP/κ=0', 'mlp_symmetry1_kappa1': '<i>W</i>-MLP/κ=1', 'mlp_symmetry3_kappa1': '<i>N</i>-MLP/κ=1'}
# {'mlp_symmetry0': 'MLP', 'mlp_symmetry1_kappa0': '<i>W</i>-MLP/κ=0', 'mlp_symmetry1_kappa1': '<i>W</i>-MLP/κ=1', 'mlp_symmetry3_kappa1': '<i>N</i>-MLP/κ=1'}
# {'mlp_symmetry0': 'MLP', 'mlp_symmetry1_kappa0': '<i>W</i>-MLP/κ=0', 'mlp_symmetry1_kappa1': '<i>W</i>-MLP/κ=1', 'mlp_symmetry3_kappa1': '<i>N</i>-MLP/κ=1'}
# ...
#     'data': [{'hovertemplate': '=MLP<br>lambda=%{x}<br>train_accu…

# %%
import plots
plots.make_lmc_plots_resnet(save_plots=False, display=True)
# Out:
# {'resnet_symmetry0': 'ResNet', 'resnet_symmetry1_kappa0': '<i>W</i>-ResNet/κ=0', 'resnet_symmetry1_kappa2': '<i>W</i>-ResNet/κ=2', 'resnet_symmetry3_kappa2': '<i>N</i>-ResNet/κ=2'}
# {'resnet_symmetry0': 'ResNet', 'resnet_symmetry1_kappa0': '<i>W</i>-ResNet/κ=0', 'resnet_symmetry1_kappa2': '<i>W</i>-ResNet/κ=2', 'resnet_symmetry3_kappa2': '<i>N</i>-ResNet/κ=2'}
# {'resnet_symmetry0': 'ResNet', 'resnet_symmetry1_kappa0': '<i>W</i>-ResNet/κ=0', 'resnet_symmetry1_kappa2': '<i>W</i>-ResNet/κ=2', 'resnet_symmetry3_kappa2': '<i>N</i>-ResNet/κ=2'}
# ...
#     'data': [{'hovertemplate': '=ResNet<br>lambda=%{x}<br>train_a…

# %%
import plots
plots.make_hausdorff_distance_plots(save_plots=False)
# Out:
# ...
#     'data': [{'alignmentgroup': 'True',
#               'hovertempl…

# %%
import plots
plots.make_activation_matching_plots_kappa_sweep(architecture="mlp", layers=None, display=True, save_plots=False)
# Out:
# Available layers: ['P_0' 'P_1' 'P_2']
# Selected layers: ['P_0' 'P_1' 'P_2']
# Available runs: ['mlp_symmetry1_kappa0.0' 'mlp_symmetry1_kappa0.01'
#  'mlp_symmetry1_kappa0.02' 'mlp_symmetry1_kappa0.05'
#  'mlp_symmetry1_kappa0.1' 'mlp_symmetry1_kappa0.2'
#  'mlp_symmetry1_kappa0.5' 'mlp_symmetry1_kappa1.0'
#  'mlp_symmetry1_kappa2.0' 'mlp_symmetry1_kappa5.0']
# ...
#     'data': [{'line': {'color': 'rgb(31, 119, 180)', 'dash': 'sol…

# %%
import plots
plots.make_activation_matching_plots_epoch_sweep(architecture="mlp", display=True, save_plots=False, correlation_mode="pearson_correlation")
# Out:
# Available layers: ['lins.0' 'lins.1' 'lins.2' 'norms.0' 'norms.1' 'norms.2' 'lins.3']
# Selected layers: ['lins.1' 'lins.2' 'lins.3']
# Available runs: ['mlp_symmetry0' 'mlp_symmetry1_kappa0' 'mlp_symmetry1_kappa1'
#  'mlp_symmetry1_kappaPerLayer' 'mlp_symmetry2' 'mlp_symmetry3_kappa0'
#  'mlp_symmetry3_kappa1' 'mlp_symmetry3_kappaPerLayer']
# ...
#     'data': [{'line': {'color': 'rgb(31, 119, 180)', 'dash': 'sol…
